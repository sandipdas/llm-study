# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
# api_key = os.getenv('OPENAI_API_KEY')
api_key = os.getenv('OPENROUTER_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
MODEL = os.getenv('OPENROUTER_API_MODEL')
MODEL = "meta-llama/llama-3.3-8b-instruct:free"
openai = OpenAI(base_url="https://openrouter.ai/api/v1",
  api_key=api_key)
# openai.api_base = "https://openrouter.ai/api/v1"
# openai.api_base = "https://api.openrouter.ai/v1"
# openai.api_key = api_key
# print(openai.api_key, openai.api_base)
# Out:
# There might be a problem with your API key? Please visit the troubleshooting notebook!

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model="meta-llama/Llama-4-Scout-17B-16E-Instruct",
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
        # response_format="json"
    )
    result = response.choices[0].message.content
    return json.loads(result)
    # return result

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
# huggingface.links

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'company page', 'url': 'https://huggingface.co/brand'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'learn page', 'url': 'https://huggingface.co/learn'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'community forum', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'github repository', 'url': 'https://github.com/huggingface'},
#   {'type': 'social media - twitter', 'url': 'https://twitter.com/huggingface'},
#   {'type': 'social media - linkedin',
#    'url': 'https://www.linkedin.com/company/huggingface/'},
#   {'type': 'community - discord',
#    'url': 'https://huggingface.co/join/discord'},
#   {'type': 'status page', 'url': 'https://status.huggingface.co/'},
#   {'type': 'docs', 'url': 'https://huggingface.co/docs'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://huggingface.co/brand'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'learn page', 'url': 'https://huggingface.co/learn'}, {'type': 'github page', 'url': 'https://github.com/huggingface'}, {'type': 'twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'linkedin page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'status page', 'url': 'https://status.huggingface.co/'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# deepseek-ai/DeepSeek-R1-0528
# Updated
# about 2 hours ago
# •
# 4.56k
# •
# 1.07k
# ByteDance-Seed/BAGEL-7B-MoT
# Updated
# 7 days ago
# •
# 6.76k
# •
# 832
# mistralai/Devstral-Small-2505
# Updated
# 3 days ago
# •
# 138k
# •
# 637
# google/gemma-3n-E4B-it-litert-preview
# Updated
# 3 days ago
# •
# 631
# sarvamai/sarvam-m
# Updated
# 1 day ago
# •
# 2.88k
# •
# 194
# Browse 1M+ models
# Spaces
# Running
# 7.39k
# 7.39k
# DeepSite
# 🐳
# Generate any application with DeepSeek
# Running
# 811
# 811
# FLUX Pro Unlimited
# 🔥
# Use the FLUX-Pro model as much as you want.
# Running
# on
# Zero
# 600
# 600
# LTX Video Fast
# 🎥
# ultra-fast video model, LTX 0.9.7 13B distilled
# Running
# on
# Zero
# 193
# 193
# Wan2.1 Fast
# 🎥
# Turn static images into animated videos
# Running
# on
# Zero
# 178
# 178
# Chatterbox TTS
# 🍿
# Expressive Zeroshot TTS
# Browse 400k+ applications
# Datasets
# open-r1/Mixture-of-Thoughts
# Updated
# 3 days ago
# •
# 8.58k
# •
# 119
# yandex/yambda
# Updated
# about 2 hours ago
# •
# 4.04k
# •
# 59
# ministere-culture/comparia-conversations
# Updated
# 9 days ago
# •
# 389
# •
# 51
# MiniMaxAI/SynLogic
# Updated
# 1 day ago
# •
# 102
# •
# 40
# disco-eth/EuroSpeech
# Updated
# 11 days ago
# •
# 34k
# •
# 75
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 757 models
# •
# 3.34k followers
# AI at Meta
# Enterprise
# company
# •
# 2.12k models
# •
# 6.19k followers
# Amazon
# company
# •
# 20 models
# •
# 3.19k followers
# Google
# company
# •
# 997 models
# •
# 14.7k followers
# Intel
# company
# •
# 226 models
# •
# 2.58k followers
# Microsoft
# company
# •
# 377 models
# •
# 12.6k followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 161 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 270 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 144,946
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 29,168
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,280
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,646
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,740
# Fast tokenizers optimized for research & production
# TRL
# 13,960
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,682
# State-of-the-art ML running directly in your browser
# smolagents
# 19,384
# Smol library to build great agents in Python
# PEFT
# 18,601
# Parameter-efficient finetuning for large language models
# Datasets
# 20,203
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,165
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,768
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
# Zhihu
# WeChat
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 40,364
# AI & ML interests
# The AI community building the future.
# Recent Activity
# mishig
# updated
# a Space
# about 20 hours ago
# huggingface/inference-playground
# akseljoonas
# new
# activity
# 1 day ago
# huggingface/documentation-images:
# Upload figures
# kargaranamir
# authored
# a paper
# 1 day ago
# Tracing Multilingual Factual Knowledge Acquisition in Pretraining
# View all activity
# Articles
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 45
# Team members
# 218
# +184
# +171
# +150
# +140
# +120
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 230k
# •
# •
# 47
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 14.9M
# •
# •
# 694
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 9.72M
# •
# 191
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# Updated
# Dec 19, 2023
# •
# 4.67M
# •
# •
# 766
# spaces
# 26
# Sort:
# 		Recently updated
# pinned
# Running
# 89
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# 177
# Inference Playground
# 🔋
# Set theme of the page based on user or system preferences
# huggingface
# about 20 hours ago
# Running
# 416
# AI Deadlines
# ⚡
# Manage project deadlines with AI assistance
# huggingface
# 9 days ago
# Running
# 8
# Space Build
# 🐨
# Generate static files for spaces
# huggingface
# 14 days ago
# Running
# 121
# InferenceSupport
# 💥
# Discussions about the Inference Providers feature on the Hub
# huggingface
# Apr 16
# Running
# 540
# Open Source Ai Year In Review 2024
# 😻
# What happened in open-source AI this year, and what’s next?
# huggingface
# Jan 8
# Expand
# 							26
# 								spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/time-series-transformer-tourism-monthly
# Time Series Forecasting
# •
# Updated
# 5 days ago
# •
# 4.51k
# •
# 21
# huggingface/timesfm-tourism-monthly
# Updated
# Mar 31
# •
# 11
# •
# 2
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 1.3k
# •
# •
# 62
# huggingface/falcon-40b-gptq
# Text Generation
# •
# Updated
# Jun 14, 2023
# •
# 29
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 20k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# Updated
# Mar 22, 2023
# •
# 241
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 20.6k
# •
# 6
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 22
# •
# 5
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 155k
# •
# •
# 81
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# Expand
# 							16
# 								models
# datasets
# 34
# Sort:
# 		Recently updated
# huggingface/documentation-images
# Viewer
# •
# Updated
# 1 day ago
# •
# 52
# •
# 3.09M
# •
# 64
# huggingface/electricity-production
# Viewer
# •
# Updated
# 7 days ago
# •
# 397
# •
# 76
# •
# 1
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# 8 days ago
# •
# 1.68k
# •
# 727
# •
# 23
# huggingface/badges
# Viewer
# •
# Updated
# Apr 8
# •
# 1
# •
# 1.86M
# •
# 43
# huggingface/policy-docs
# Updated
# Mar 20
# •
# 1.28k
# •
# 11
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# Mar 15
# •
# 69
# •
# 664
# •
# 7
# huggingface/gemini-results-new-cs-papers-2025-02-11-100-230-updated
# Viewer
# •
# Updated
# Feb 17
# •
# 130
# •
# 42
# huggingface/wiki_dpr
# Updated
# Feb 5
# •
# 148
# huggingface/paper-central-data
# Viewer
# •
# Updated
# Jan 4
# •
# 124k
# •
# 123
# •
# 9
# huggingface/community-science-paper-v2
# Viewer
# •
# Updated
# Dec 22, 2024
# •
# 5.03k
# •
# 34
# •
# 7
# Expand
# 							34
# 								datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# company page
# Webpage Title:
# Brand assets - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face · Brand assets
# HF Logos
# .svg
# .png
# .ai
# .svg
# .png
# .ai
# .svg
# .png
# .ai
# HF Colors
# #FFD21E
# #FF9D00
# #6B7280
# HF Bio
# Hugging Face is the collaboration platform for the machine learning community.
#
# The Hugging Face Hub works as a central place where anyone can share, explore, discover, and experiment with open-source ML. HF empowers the next generation of machine learning engineers, scientists, and end users to learn, collaborate and share their work to build an open and ethical AI future together.
#
# With the fast-growing community, some of the most used open-source ML libraries and tools, and a talented science team exploring the edge of tech, Hugging Face is at the heart of the AI revolution.
# Copy to clipboard
# HF Universe
# Find other assets available for use from the Hugging Face brand universe
# here
# .
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# pricing page
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Users and organizations already use the Hub as a collaboration platform,
# we’re making it easy to seamlessly and scalably launch ML compute directly from the Hub.
# HF Hub
# Collaborate on Machine Learning
# Host unlimited public models, datasets
# Create unlimited orgs with no member limits
# Access the latest ML tools and open source
# Community support
# Forever
# Free
# PRO
# PRO Account
# Unlock advanced HF features
# ZeroGPU and Dev Mode for Spaces
# Free credits across all Inference Providers
# Get early access to upcoming features
# Show your support with a Pro badge
# Subscribe for
# $9
# /month
# Enterprise Hub
# Accelerate your AI roadmap
# SSO and SAML support
# Select data location with Storage Regions
# Precise actions reviews with Audit logs
# Granular access control with Resource groups
# Centralized token control and approval
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# 5x more ZeroGPU quota for all org members
# Deploy Inference on your own Infra
# Managed billing with yearly commits
# Priority support
# Starting at
# $20
# per user per month
# Spaces Hardware
# Upgrade your Space compute
# Free CPUs
# Build more advanced Spaces
# 7 optimized hardware available
# From CPU to GPU to Accelerators
# Starting at
# $0
# /hour
# Inference Endpoints
# Deploy models on fully managed infrastructure
# Deploy dedicated Endpoints in seconds
# Keep your costs low
# Fully-managed autoscaling
# Enterprise security
# Starting at
# $0.032
# /hour
# Need support to accelerate AI in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $4.00
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# 16
# 32GB
# $0.54
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $4.00
# 2
# 160GB
# $8.00
# 4
# 320GB
# $16.00
# 8
# 640GB
# $32.00
# aws
# NVIDIA H200
# 1
# 141GB
# $5.00
# 2
# 282GB
# $10.00
# 4
# 564GB
# $20.00
# 8
# 1128GB
# $40.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# PRO Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get PRO
# ($9/month)
# ZeroGPU
# : Get 5x usage quota and highest GPU queue priority
# Spaces Hosting
# : Create ZeroGPU Spaces with H200 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# Inference Providers
# : Get $2 included credits across all Inference Providers
# Dataset Viewer
# : Activate it on private datasets
# Blog Articles
# : Publish articles to the Hugging Face blog
# Social Posts
# : Share short updates with the community
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# enterprise page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Enterprise Hub
# Enterprise-ready version of the world’s leading AI platform
# Subscribe to
# Enterprise Hub
# for $20/user/month with your Hub organization
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Extra Private Storage
# Get an additional 1 TB of private storage for each member of your organization (then $25/month per extra TB).
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Enterprise Hub
# or
# Talk to sales
# NVIDIA
# Enterprise
# company
# •
# 373 models
# •
# 27.3k followers
# Shopify
# Enterprise
# company
# •
# 465 followers
# AMD
# Enterprise
# company
# •
# 142 models
# •
# 1.56k followers
# Arm
# Enterprise
# company
# •
# 204 followers
# Qwen
# Enterprise
# company
# •
# 280 models
# •
# 32.7k followers
# Xsolla
# Enterprise
# company
# •
# 137 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 147 followers
# Nutanix
# Enterprise
# company
# •
# 261 models
# •
# 102 followers
# creditkarma
# Enterprise
# company
# •
# 69 followers
# Technology Innovation Institute
# Enterprise
# company
# •
# 101 models
# •
# 1.41k followers
# HiddenLayer
# Enterprise
# company
# •
# 1 model
# •
# 73 followers
# Skywork
# Enterprise
# company
# •
# 40 models
# •
# 707 followers
# Stability AI
# Enterprise
# company
# •
# 107 models
# •
# 24k followers
# BCG X
# Enterprise
# company
# •
# 40 followers
# Infosys Limited
# Enterprise
# company
# •
# 2 models
# •
# 845 followers
# AI at Meta
# Enterprise
# company
# •
# 2.12k models
# •
# 6.19k followers
# Snowflake
# Enterprise
# company
# •
# 23 models
# •
# 520 followers
# Together
# Enterprise
# company
# •
# 33 models
# •
# 606 followers
# LiveRAG by AIIR
# Enterprise
# company
# •
# 130 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 3 models
# •
# 282 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 10 models
# •
# 115 followers
# Jusbrasil
# Enterprise
# company
# •
# 98 followers
# Aledade Inc
# Enterprise
# company
# •
# 72 followers
# Chegg Inc
# Enterprise
# company
# •
# 86 followers
# Johnson & Johnson
# Enterprise
# company
# •
# 63 followers
# MiniMax
# Enterprise
# company
# •
# 2 models
# •
# 693 followers
# Liquid AI
# Enterprise
# company
# •
# 195 followers
# Twelve Labs
# Enterprise
# company
# •
# 45 followers
# Meta Llama
# Enterprise
# company
# •
# 70 models
# •
# 45.5k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 300 followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 225 followers
# ServiceNow
# Enterprise
# company
# •
# 506 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 270 followers
# Fidelity Investments
# Enterprise
# company
# •
# 147 followers
# Mercedes-Benz AG
# Enterprise
# company
# •
# 165 followers
# IBM Granite
# Enterprise
# company
# •
# 117 models
# •
# 1.8k followers
# H2O.ai
# Enterprise
# company
# •
# 71 models
# •
# 426 followers
# HyperCLOVA X
# Enterprise
# company
# •
# 3 models
# •
# 325 followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 161 followers
# Widn AI
# Enterprise
# company
# •
# 48 followers
# Lightricks
# Enterprise
# company
# •
# 13 models
# •
# 997 followers
# Mistral AI_
# Enterprise
# company
# •
# 28 models
# •
# 8.86k followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# CodeAgents + Structure: A Better Way to Execute Actions
# By
# akseljoonas
# May 28, 2024
# •
# 17
# Community Articles
# view all
# Interactive Tools for machine learning, deep learning, and math
# By
# Suzana
# •
# 3 days ago
# •
# 30
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 587
# Bigger isn't always better: how to choose the most efficient model for context-specific tasks 🌱🧑🏼‍💻
# By
# sasha
# •
# 1 day ago
# •
# 12
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 271
# Falcon-Arabic: A Breakthrough in Arabic Language Models
# By
# tiiuae
# and 7 others
# •
# 8 days ago
# •
# 28
# OpenEvolve: An Open Source Implementation of Google DeepMind's AlphaEvolve
# By
# codelion
# •
# 9 days ago
# •
# 17
# Fine-Tuning Your First Large Language Model (LLM) with PyTorch and Hugging Face
# By
# dvgodoy
# •
# Feb 11
# •
# 37
# Major PHYBench Update Released
# By
# StarThomas1002
# and 1 other
# •
# 4 days ago
# •
# 7
# Mitigating False Negatives in Multiple Negatives Ranking Loss for Retriever Training
# By
# dragonkue
# •
# 4 days ago
# •
# 5
# AgenticSeek: Running Manus AI Locally with Deepseek & Qwen (Open Source Tool)
# By
# lynn-mikami
# •
# 5 days ago
# •
# 5
# Let's talk about LLM evaluation
# By
# clefourrier
# •
# May 23, 2024
# •
# 174
# How to Use FastAPI MCP Server: A Complete Guide
# By
# lynn-mikami
# •
# Apr 11
# •
# 36
# DeepWiki: Best AI Documentation Generator for Any Github Repo
# By
# lynn-mikami
# •
# Apr 28
# •
# 25
# Good answers are not necessarily factual answers: an analysis of hallucination in leading LLMs
# By
# davidberenstein1957
# and 1 other
# •
# 22 days ago
# •
# 32
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 138
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 81
# Mastering Tensor Dimensions in Transformers
# By
# not-lain
# •
# Jan 12
# •
# 62
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 68
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 142
# Navigating the RLHF Landscape: From Policy Gradients to PPO, GAE, and DPO for LLM Alignment
# By
# NormalUhr
# •
# Feb 11
# •
# 39
# 🐯 Liger GRPO meets TRL
# By
# shisahni
# May 25, 2025
# guest
# •
# 25
# Dell Enterprise Hub is all you need to build AI on premises
# By
# jeffboudier
# May 23, 2025
# •
# 15
# Tiny Agents in Python: a MCP-powered agent in ~70 lines of code
# By
# celinah
# May 23, 2025
# •
# 90
# Exploring Quantization Backends in Diffusers
# By
# derekl35
# May 21, 2025
# •
# 24
# nanoVLM: The simplest repository to train your VLM in pure PyTorch
# By
# ariG23498
# May 21, 2025
# •
# 114
# Microsoft and Hugging Face expand collaboration
# By
# jeffboudier
# May 19, 2025
# •
# 20
# The Transformers Library: standardizing model definitions
# By
# lysandre
# May 15, 2025
# •
# 104
# Improving Hugging Face Model Access for Kaggle Users
# By
# roseberryv
# May 14, 2025
# •
# 25
# Blazingly fast whisper transcriptions with Inference Endpoints
# By
# mfuntowicz
# May 13, 2025
# •
# 65
# Vision Language Models (Better, Faster, Stronger)
# By
# merve
# May 12, 2025
# •
# 385
# LeRobot Community Datasets: The “ImageNet” of Robotics — When and How?
# By
# danaaubakirova
# May 11, 2025
# •
# 49
# How to Build an MCP Server with Gradio
# By
# abidlabs
# April 30, 2025
# •
# 126
# Welcoming Llama Guard 4 on Hugging Face Hub
# By
# merve
# April 29, 2025
# •
# 37
# The 4 Things Qwen-3's Chat Template Teaches Us
# By
# cfahlgren1
# April 30, 2025
# •
# 47
# Previous
# 1
# 2
# 3
# ...
# 42
# Next
# Community Articles
# Sort:
# 		Trending
# Interactive Tools for machine learning, deep learning, and math
# By
# Suzana
# •
# 3 days ago
# •
# 30
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 587
# Bigger isn't always better: how to choose the most efficient model for context-specific tasks 🌱🧑🏼‍💻
# By
# sasha
# •
# 1 day ago
# •
# 12
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 271
# Falcon-Arabic: A Breakthrough in Arabic Language Models
# By
# tiiuae
# and 7 others
# •
# 8 days ago
# •
# 28
# OpenEvolve: An Open Source Implementation of Google DeepMind's AlphaEvolve
# By
# codelion
# •
# 9 days ago
# •
# 17
# Fine-Tuning Your First Large Language Model (LLM) with PyTorch and Hugging Face
# By
# dvgodoy
# •
# Feb 11
# •
# 37
# Major PHYBench Update Released
# By
# StarThomas1002
# and 1 other
# •
# 4 days ago
# •
# 7
# Mitigating False Negatives in Multiple Negatives Ranking Loss for Retriever Training
# By
# dragonkue
# •
# 4 days ago
# •
# 5
# AgenticSeek: Running Manus AI Locally with Deepseek & Qwen (Open Source Tool)
# By
# lynn-mikami
# •
# 5 days ago
# •
# 5
# Let's talk about LLM evaluation
# By
# clefourrier
# •
# May 23, 2024
# •
# 174
# How to Use FastAPI MCP Server: A Complete Guide
# By
# lynn-mikami
# •
# Apr 11
# •
# 36
# DeepWiki: Best AI Documentation Generator for Any Github Repo
# By
# lynn-mikami
# •
# Apr 28
# •
# 25
# Good answers are not necessarily factual answers: an analysis of hallucination in leading LLMs
# By
# davidberenstein1957
# and 1 other
# •
# 22 days ago
# •
# 32
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 138
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 81
# Mastering Tensor Dimensions in Transformers
# By
# not-lain
# •
# Jan 12
# •
# 62
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 68
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 142
# Navigating the RLHF Landscape: From Policy Gradients to PPO, GAE, and DPO for LLM Alignment
# By
# NormalUhr
# •
# Feb 11
# •
# 39
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# learn page
# Webpage Title:
# Hugging Face - Learn
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Learn
# LLM Course
# This course will teach you about large language models using libraries from the HF ecosystem
# MCP Course
# This course will teach you about Model Context Protocol
# Agents Course
# Learn to build and deploy your own AI agents
# Deep RL Course
# This course will teach you about deep reinforcement learning using libraries from the HF ecosystem
# Community Computer Vision Course
# This course will teach you about computer vision ML using libraries and models from the HF ecosystem
# Audio Course
# Learn to apply transformers to audio data using libraries from the HF ecosystem
# Open-Source AI Cookbook
# A collection of open-source-powered notebooks by AI builders, for AI builders
# ML for Games Course
# This course will teach you about integrating AI models your game and using AI tools in your game development workflow
# Diffusion Course
# Learn about diffusion models & how to use them with diffusers
# ML for 3D Course
# Learn about 3D ML with libraries from the HF ecosystem
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# github page
# Webpage Title:
# Hugging Face · GitHub
# Webpage Contents:
# Skip to content
# Navigation Menu
# Toggle navigation
# Sign in
# Appearance settings
# huggingface
# Product
# GitHub Copilot
# Write better code with AI
# GitHub Models
# New
# Manage and compare prompts
# GitHub Advanced Security
# Find and fix vulnerabilities
# Actions
# Automate any workflow
# Codespaces
# Instant dev environments
# Issues
# Plan and track work
# Code Review
# Manage code changes
# Discussions
# Collaborate outside of code
# Code Search
# Find more, search less
# Explore
# Why GitHub
# All features
# Documentation
# GitHub Skills
# Blog
# Solutions
# By company size
# Enterprises
# Small and medium teams
# Startups
# Nonprofits
# By use case
# DevSecOps
# DevOps
# CI/CD
# View all use cases
# By industry
# Healthcare
# Financial services
# Manufacturing
# Government
# View all industries
# View all solutions
# Resources
# Topics
# AI
# DevOps
# Security
# Software Development
# View all
# Explore
# Learning Pathways
# Events & Webinars
# Ebooks & Whitepapers
# Customer Stories
# Partners
# Executive Insights
# Open Source
# GitHub Sponsors
# Fund open source developers
# The ReadME Project
# GitHub community articles
# Repositories
# Topics
# Trending
# Collections
# Enterprise
# Enterprise platform
# AI-powered developer platform
# Available add-ons
# GitHub Advanced Security
# Enterprise-grade security features
# Copilot for business
# Enterprise-grade AI features
# Premium Support
# Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
# Search
# Clear
# Search syntax tips
# Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
# Cancel
# Submit feedback
# Saved searches
# Use saved searches to filter your results more quickly
# Cancel
# Create saved search
# Sign in
# Sign up
# Appearance settings
# Resetting focus
# You signed in with another tab or window.
# Reload
# to refresh your session.
# You signed out in another tab or window.
# Reload
# to refresh your session.
# You switched accounts on another tab or window.
# Reload
# to refresh your session.
# Dismiss alert
# Hugging Face
# The AI community building the future.
# Verified
# We've verified that the organization
# huggingface
# controls the domain:
# huggingface.co
# Learn more about verified organizations
# 49.5k
# followers
# NYC + Paris
# https://huggingface.co/
# X
# @huggingface
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# 0
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# Python
# 145k
# 29.2k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# Python
# 29.2k
# 6k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Python
# 20.2k
# 2.8k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 18.6k
# 1.9k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 8.8k
# 1.1k
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 2.9k
# 540
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# Handlebars
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Svelte
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 317 repositories
# pyspark_huggingface
# Public
# PySpark custom data source for Hugging Face Datasets
# huggingface/pyspark_huggingface’s past year of commit activity
# Python
# 4
# Apache-2.0
# 4
# 0
# 2
# Updated
# May 29, 2025
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# huggingface/transformers’s past year of commit activity
# Python
# 144,947
# Apache-2.0
# 29,149
# 1,052
# (2 issues need help)
# 741
# Updated
# May 29, 2025
# huggingface.js
# Public
# Utilities to use the Hugging Face Hub API
# huggingface/huggingface.js’s past year of commit activity
# TypeScript
# 2,111
# MIT
# 410
# 106
# (5 issues need help)
# 55
# Updated
# May 29, 2025
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# huggingface/accelerate’s past year of commit activity
# Python
# 8,768
# Apache-2.0
# 1,114
# 84
# (4 issues need help)
# 16
# Updated
# May 29, 2025
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# huggingface/diffusers’s past year of commit activity
# Python
# 29,168
# Apache-2.0
# 5,994
# 493
# (12 issues need help)
# 190
# Updated
# May 29, 2025
# text-generation-inference
# Public
# Large Language Model Text Generation Inference
# huggingface/text-generation-inference’s past year of commit activity
# Python
# 10,165
# Apache-2.0
# 1,194
# 251
# 29
# Updated
# May 29, 2025
# optimum-intel
# Public
# 🤗 Optimum Intel: Accelerate inference with Intel optimization tools
# huggingface/optimum-intel’s past year of commit activity
# Jupyter Notebook
# 466
# Apache-2.0
# 131
# 28
# 18
# Updated
# May 29, 2025
# inference-playground
# Public
# huggingface/inference-playground’s past year of commit activity
# Svelte
# 40
# MIT
# 3
# 0
# 2
# Updated
# May 29, 2025
# optimum-habana
# Public
# Easy and lightning fast training of 🤗 Transformers on Habana Gaudi processor (HPU)
# huggingface/optimum-habana’s past year of commit activity
# Python
# 186
# Apache-2.0
# 259
# 17
# (1 issue needs help)
# 38
# Updated
# May 29, 2025
# candle
# Public
# Minimalist ML framework for Rust
# huggingface/candle’s past year of commit activity
# Rust
# 17,276
# Apache-2.0
# 1,114
# 420
# (5 issues need help)
# 117
# Updated
# May 29, 2025
# View all repositories
# People
# View all
# Top languages
# Python
# Jupyter Notebook
# Rust
# TypeScript
# JavaScript
# Most used topics
# pytorch
# machine-learning
# nlp
# transformers
# deep-learning
# Footer
# © 2025 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# twitter page
# Webpage Title:
# No title found
# Webpage Contents:
# JavaScript is not available.
# We’ve detected that JavaScript is disabled in this browser. Please enable JavaScript or switch to a supported browser to continue using x.com. You can see a list of supported browsers in our Help Center.
# Help Center
# Terms of Service
# Privacy Policy
# Cookie Policy
# Imprint
# Ads info
# © 2025 X Corp.
# Something went wrong, but don’t fret — let’s give it another shot.
# Try again
# Some privacy related extensions may cause issues on x.com. Please disable them and try again.
#
#
#
# linkedin page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# View all 536 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning @ 🤗 Hugging Face
# 6h
# Report this post
# Deepseek just dropped a v2 of R1 and it and it's ready to roll. Here are the first few things I'll try:
#
# - agentic and MCP applications with complex tasks
# - generate a synthetic dataset to SFT a smaller model
# - vibe code some HARD apps
# Hugging Face
# inference providers are already live. let's go!
# https://lnkd.in/e9JYDta2
# …more
# 110
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 64,677 followers
# 7h
# Report this post
# WILD! 💸 Now
# Hyperbolic
# Labs has also joined us as a sponsor--the first 1000 participants will be getting $15 worth of API credits for building their agentic apps at the Hackathon!
#
# 👑 Agents & MCP Hackathon 2025 just got even bigger!
# Join right now:
# https://lnkd.in/g7yp9HKG
# 👉👉Make sure to join the
# Hugging Face
# organization to stay updated on the latest guidelines and to submit your entries for the biggest online event of summer 2025!
#
# Cash & Credit awards to participants and winners worth $95000+ up for grabs 🤑
# Agents-MCP-Hackathon (Agents-MCP-Hackathon)
# huggingface.co
# 14
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face 🤗
# 1d
# Report this post
# Open-sourcing nanoDiT -- an educational repository to show rectified-flow training of class-conditional DiTs for image generation (~600 LoC).
#
# The repo aims at bringing the essential components while striving to be minimal and reasonable:
#
# 1️⃣ Pixel-space instead of latent-space because VAE is a separate magic which was purposefully discarded from this repo.
# 2️⃣ DiT as the base architecture as this is the core behind modern models like Flux.
# 3️⃣ Class-conditional to show how to embed conditions other than just timesteps.
# 4️⃣ Rectified flows for a simpler alternative to DDPM-style diffusion training.
# 5️⃣ You can fiddle around with the model and the training setup on your local laptop.
#
# Hope that helps:
# https://lnkd.in/gAQYtdRa
# 253
# 13 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Aksel Joonas Reedi
# Agentic @ Hugging Face 🤗
# 22h
# Report this post
# 1.5 months into my internship at
# Hugging Face
# , and I just shipped my first research contribution 🚀
#
# I've been diving deep into how AI agents execute actions. The current state-of-the-art choices are:
# → JSON agents (reliable but too rigid)
# → CodeAgents (flexible, but parsing errors kill performance)
#
# But what if I told you I found a third option that beats both? 👇
#
#
# The problem I discovered: 🤕
#
# After analyzing 15,724 agent traces across GAIA, MATH, Frames & SimpleQA, I found that parsing errors in the first action reduce success rates by 21.3%. That’s a lot!
#
# JSON agents avoid this but lack support for loops and state, which are usually required in real-world use cases. CodeAgents are expressive but fragile when extracting Python from markdown.
#
# My approach: Structured CodeAgents 👷🧠
#
# Instead of generating code in markdown blocks, what if agents generated both thoughts AND code in a structured JSON format?
#
# The results were surprising:
# Parsing errors went to 0, and performance doubled compared to JSON agents. Structured generation consistently wins for capable models. 📈
#
# Claude-4-Sonnet: 32% → 65% → 68% (JSON → Code → Structured)
# GPT-4o: 34% → 53% → 54%
# Qwen-235B: 45% → 48% → 56%
#
# But there’s a bit of a catch ⚠️:
#
# There's a "structure tax." Smaller models completely fail when forced to handle JSON formatting + Python syntax + reasoning simultaneously. The cognitive overhead is too much. The Python generated in JSON tags usually has syntax errors and breaks down the agent.
#
# What this means for agent builders:
# Choose your architecture based on your model's capability. For frontier models, structured generation is a win. For smaller models, stick with simpler approaches.
#
# Full research details in my blog post:
# https://lnkd.in/dN8Mj5D4
# Big thanks to
# Aymeric Roucher
# ,
# Amir Mahla
# , and
# Albert Villanova
# for the mentorship and support 🤗
# #AI
# #MachineLearning
# #Research
# #HuggingFace
# #Agents
# 263
# 20 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 64,677 followers
# 1d
# Edited
# Report this post
# 🚨MAJOR LAUNCH: Agents & MCP Hackathon is officially happening!🤖
#
# June 2 - 8, 2025 | $10,000 in cash-prizes | 1 week of pure AI Agent action
#
# First major completely online event focused on
# Anthropic
# 's MCP!
#
# Participants get Free API credits | Sponsored by
# SambaNova Systems
# 🤯
#
# Register here for this epic run:
# https://lnkd.in/g7yp9HKG
# 102
# 7 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Freddy Boulton
# Software Engineer @ 🤗
# 19h
# Report this post
# 🚀 Gradio Hackathon: June 2-8
#
# $10,000+ in prizes for the most innovative agentic apps & MCP servers!
#
# New to this? No problem:
# ✅ Free office hours
# ✅ Free AI platform credits (courtesy of
# Hugging Face
# ,
# Anthropic
# ,
# Mistral AI
# ,
# SambaNova Systems
# ,
# LlamaIndex
# )
#
# Join here:
# https://lnkd.in/e2Hywiet
# 31
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face 🤗
# 1d
# Report this post
# Open-sourcing nanoDiT -- an educational repository to show rectified-flow training of class-conditional DiTs for image generation (~600 LoC).
#
# The repo aims at bringing the essential components while striving to be minimal and reasonable:
#
# 1️⃣ Pixel-space instead of latent-space because VAE is a separate magic which was purposefully discarded from this repo.
# 2️⃣ DiT as the base architecture as this is the core behind modern models like Flux.
# 3️⃣ Class-conditional to show how to embed conditions other than just timesteps.
# 4️⃣ Rectified flows for a simpler alternative to DDPM-style diffusion training.
# 5️⃣ You can fiddle around with the model and the training setup on your local laptop.
#
# Hope that helps:
# https://lnkd.in/gAQYtdRa
# 253
# 13 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗 | Google Developer Expert in Machine Learning, MSc Candidate in Data Science
# 1d
# Report this post
# Data Studio of
# Hugging Face
# is so underrated 💗
#
# I had an issue with a line in our dataset → fixed it in 2 secs in place without writing SQL (not a fan 🪭 also too lazy)
#
# if you've an error it has an assistant that fixes for you (see second step below, I didn't write the prompt!)
# …more
# 59
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Yuvraj Sharma
# ML @ 🤗 Hugging Face
# 22h
# Report this post
# 🔥Update: We've confirmed
# Mistral AI
# as our fourth major sponsor, joining
# Anthropic
# ,
# SambaNova Systems
# , and
# LlamaIndex
# . A stellar lineup indeed!
# Gradio
# Agents & MCP Hackathon is now clearly the premier MCP/Agent ecosystem event of 2025.
#
# Register here to join and participate virtually:
# https://lnkd.in/gx3uHHFx
# Agents-MCP-Hackathon (Agents-MCP-Hackathon)
# huggingface.co
# 73
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face 🤗
# 1d
# Report this post
# Open-sourcing nanoDiT -- an educational repository to show rectified-flow training of class-conditional DiTs for image generation (~600 LoC).
#
# The repo aims at bringing the essential components while striving to be minimal and reasonable:
#
# 1️⃣ Pixel-space instead of latent-space because VAE is a separate magic which was purposefully discarded from this repo.
# 2️⃣ DiT as the base architecture as this is the core behind modern models like Flux.
# 3️⃣ Class-conditional to show how to embed conditions other than just timesteps.
# 4️⃣ Rectified flows for a simpler alternative to DDPM-style diffusion training.
# 5️⃣ You can fiddle around with the model and the training setup on your local laptop.
#
# Hope that helps:
# https://lnkd.in/gAQYtdRa
# 253
# 13 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Google DeepMind
# Research Services
# London, London
# Cohere
# Software Development
# Toronto, Ontario
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app
#
#
#
# community page
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# Can I ask a question if I have a good idea but can't write programs?
# Beginners
# 7
# 13
# May 29, 2025
# PRD to HLD,LLD and task breakdown via cursor
# Beginners
# 0
# 8
# May 29, 2025
# Ajay Hinduja Geneva, Switzerland Newbie Introduction
# Beginners
# 1
# 7
# May 29, 2025
# Error using Trainer with Colab notebook, anyone have a solution?
# 🤗Transformers
# 1
# 4
# May 29, 2025
# Invalid token or no access to Hugging Face
# Beginners
# 3
# 1448
# May 29, 2025
# Building a Multi Lingual Multi Task Model in Finance Domain
# Models
# 1
# 15
# May 28, 2025
# How to retrive in this scenario?
# Research
# 0
# 4
# May 29, 2025
# Nari-labs Dia-1.6B Is there a page where I can use it without limitations?
# Beginners
# 1
# 7
# May 28, 2025
# Running and testing / BharatGPT-3B-Indic
# Models
# 5
# 15
# May 28, 2025
# How can I extract all conversations from my ChatGPT .json export files (I’m not a developer)?
# Beginners
# 2
# 7
# May 28, 2025
# How to build NLP querying system for text document that returns correct facts
# Beginners
# 1
# 9
# May 28, 2025
# First_agent_template issue app.py
# Beginners
# 4
# 26
# May 28, 2025
# ValueError: Evaluation module cache file doesn't exist
# Beginners
# 1
# 7
# May 28, 2025
# How do I get the Ai model
# Beginners
# 1
# 23
# May 28, 2025
# Can't submit my paper to daily papers
# 🤗Hub
# 1
# 16
# May 28, 2025
# How does Q, K, V differ in LLM?
# 🤗Transformers
# 1
# 16
# May 28, 2025
# Namrata Hinduja Geneva Beginner to HuggingFace Platform
# Beginners
# 1
# 16
# May 28, 2025
# Error : No API Found
# Spaces
# 11
# 1080
# May 28, 2025
# Need help to find old Embeddings I lost during PC installation
# Models
# 4
# 21
# May 27, 2025
# Constantly getting 401 unauthorized
# Beginners
# 13
# 291
# May 23, 2025
# LoRA training with accelerate / deepspeed
# DeepSpeed
# 3
# 2205
# May 28, 2025
# Space won't start - logs not found
# Spaces
# 21
# 2368
# May 28, 2025
# ValueError: Invalid pattern: '**' can only be an entire path component
# 🤗Datasets
# 3
# 3349
# May 26, 2025
# Inference API stopped working
# Inference Endpoints on the Hub
# 49
# 2577
# May 27, 2025
# Why can't I reproduce benchmark scores from papers like Phi, Llama, or Qwen? Am I doing something wrong or is this normal?
# Models
# 1
# 18
# May 28, 2025
# Chapter 1 questions
# Course
# 107
# 23475
# May 28, 2025
# Alternative options for API endpoints
# Course
# 1
# 125
# May 28, 2025
# Together.AI inference with DeepSeek
# Spaces
# 1
# 10
# May 28, 2025
# How to make a model respect static UI layout and generate only overlay characters (ControlNet / SDXL / IPAdapter?)
# Spaces
# 1
# 10
# May 28, 2025
# Optimal Approach for Fine-Tuning LayoutLMv3 for Token Classification with 80 Labels
# Models
# 3
# 15
# May 26, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# status page
# Webpage Title:
#
# Hugging Face status
#
# Webpage Contents:
# Status
# Maintenance
# Previous incidents
# Get updates
# Get status updates
# Get e-mail notifications whenever Hugging Face creates, updates or resolves an incident.
# Subscribe to specific components
# Current status by service
# Huggingface Hub
# Git Hosting and Serving
# HF Inference
# HF Endpoints
# Inference Endpoints UI
# Inference Endpoints API
# Spaces
# Spaces Proxy
# Subscribe
# All services are online
# Last updated on May 29 at 10:00am EDT
# Current status by service
# Operational
# Huggingface Hub
# 30 days ago
# 60 days ago
# 90 days ago
# Today
# Git Hosting and Serving
# 30 days ago
# 60 days ago
# 90 days ago
# Today
# HF Inference
# 30 days ago
# 60 days ago
# 90 days ago
# Today
# HF Endpoints
# Operational
# Inference Endpoints UI
# 30 days ago
# 60 days ago
# 90 days ago
# Today
# Inference Endpoints API
# 30 days ago
# 60 days ago
# 90 days ago
# Today
# Spaces
# Operational
# Spaces Proxy
# 30 days ago
# 60 days ago
# 90 days ago
# Today
# Powered by
# Better Stack
#
#
#
# documentation page
# Webpage Title:
# Hugging Face - Documentation
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Documentations
# Hub & Client Libraries
# Hub
# Host Git-based models, datasets, and Spaces on the HF Hub
# Hub Python Library
# Python client to interact with the Hugging Face Hub
# Huggingface.js
# JavaScript libraries for Hugging Face with built-in TS types
# Tasks
# Explore demos, models, and datasets for any ML tasks
# Dataset viewer
# API for metadata, stats, and content of HF Hub datasets
# Deployment & Inference
# Inference Providers
# Call 200k+ models hosted by our 10+ Inference partners
# Inference Endpoints (dedicated)
# Deploy models on dedicated & fully managed infrastructure on HF
# Amazon SageMaker
# Train/deploy Transformers models with SageMaker/HF DLCs
# Text Generation Inference
# Serve language models with TGI optimized toolkit
# Text Embeddings Inference
# Serve embeddings models with TEI optimized toolkit
# Core ML Libraries
# Transformers
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# State-of-the-art Diffusion models in PyTorch
# Datasets
# Access & share datasets for any ML tasks
# Transformers.js
# State-of-the-art ML running directly in your browser
# Tokenizers
# Fast tokenizers optimized for research & production
# Evaluate
# Evaluate and compare models performance
# timm
# State-of-the-art vision models: layers, optimizers, and utilities
# Sentence Transformers
# Embeddings, Retrieval, and Reranking
# Training & Optimization
# PEFT
# Parameter-efficient finetuning for large language models
# Accelerate
# Train PyTorch models with multi-GPU, TPU, mixed precision
# Optimum
# Optimize HF Transformers for faster training/inference
# AWS Trainium & Inferentia
# Train/deploy Transformers/Diffusers on AWS
# TRL
# Train transformers LMs with reinforcement learning
# Safetensors
# Safe way to store/distribute neural network weights
# Bitsandbytes
# Optimize and quantize models with bitsandbytes
# Lighteval
# All-in-one toolkit to evaluate LLMs across multiple backends
# Collaboration & Extras
# Gradio
# Build ML demos and web apps with a few lines of Python
# smolagents
# Smol library to build great agents in Python
# AutoTrain
# AutoTrain API and UI for seamless model training
# Chat UI
# Open source chat frontend powering HuggingChat
# Leaderboards
# Create custom Leaderboards on Hugging Face
# Argilla
# Collaboration tool for building high-quality datasets
# Distilabel
# Framework for synthetic data generation and AI feedback
# Community
# Blog
# Learn
# Discord
# Forum
# Github
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://huggingface.co/brand'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'learn page', 'url': 'https://huggingface.co/learn'}, {'type': 'github page', 'url': 'https://github.com/huggingface'}, {'type': 'twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'linkedin page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nCommunity\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\ndeepseek-ai/DeepSeek-R1-0528\nUpdated\nabout 2 hours ago\n•\n4.56k\n•\n1.07k\nByteDance-Seed/BAGEL-7B-MoT\nUpdated\n7 days ago\n•\n6.76k\n•\n832\nmistralai/Devstral-Small-2505\nUpdated\n3 days ago\n•\n138k\n•\n637\ngoogle/gemma-3n-E4B-it-litert-preview\nUpdated\n3 days ago\n•\n631\nsarvamai/sarvam-m\nUpdated\n1 day ago\n•\n2.88k\n•\n194\nBrowse 1M+ models\nSpaces\nRunning\n7.39k\n7.39k\nDeepSite\n🐳\nGenerate any application with DeepSeek\nRunning\n811\n811\nFLUX Pro Unlimited\n🔥\nUse the FLUX-Pro model as much as you want.\nRunning\non\nZero\n600\n600\nLTX Video Fast\n🎥\nultra-fast video model, LTX 0.9.7 13B distilled\nRunning\non\nZero\n193\n193\nWan2.1 Fast\n🎥\nTurn static images into animated videos\nRunning\non\nZero\n179\n179\nChatterbox TTS\n🍿\nExpressive Zeroshot TTS\nBrowse 400k+ applications\nDatasets\nopen-r1/Mixture-of-Thoughts\nUpdated\n3 days ago\n•\n8.58k\n•\n119\nyandex/yambda\nUpdated\nabout 2 hours ago\n•\n4.04k\n•\n59\nministere-culture/comparia-conversations\nUpdated\n9 days ago\n•\n389\n•\n51\nMiniMaxAI/SynLogic\nUpdated\n1 day ago\n•\n102\n•\n40\ndisco-eth/EuroSpeech\nUpdated\n11 days ago\n•\n34k\n•\n75\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n757 models\n•\n3.34k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.12k models\n•\n6.19k followers\nAmazon\ncompany\n•\n20 models\n•\n3.19k followers\nGoogle\ncompany\n•\n997 models\n•\n14.7k followers\nIntel\ncompany\n•\n226 models\n•\n2.58k followers\nMicrosoft\ncompany\n•\n377 models\n•\n12.6k followers\nGrammarly\nEnterprise\ncompany\n•\n10 models\n•\n161 followers\nWriter\nEnterprise\ncompany\n•\n21 models\n•\n270 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n144,946\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n29,168\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,280\nSafe way to store/distribute neural network weights\nHub Python Library\n2,646\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,740\nFast tokenizers optimized for research & production\nTRL\n13,960\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,682\nState-of-the-art ML running directly in your browser\nsmolagents\n19,384\nSmol library to build great agents in Python\nPEFT\n18,601\nParameter-efficient finetuning for large language models\nDatasets\n20,203\nAccess & share datasets for any ML tasks\nText Generation ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://huggingface.co/brand'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog', 'url': 'https://huggingface.co/blog'}, {'type': 'learn page', 'url': 'https://huggingface.co/learn'}, {'type': 'github page', 'url': 'https://github.com/huggingface'}, {'type': 'twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'linkedin page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'status page', 'url': 'https://status.huggingface.co/'}, {'type': 'discord page', 'url': 'https://huggingface.co/join/discord'}]}
# # Hugging Face: The AI Community Building the Future
# ## Overview
# Hugging Face is a collaboration platform for the machine learning community to build, share, and use artificial intelligence models, datasets, and applications. With over 50,000 organizations using their platform, Hugging Face is at the forefront of democratizing good machine learning.
#
# ## Our Mission
# We are on a mission to make machine learning accessible to everyone. Our platform provides a space for the community to come together, share knowledge, and build innovative AI solutions.
#
# ## Community
# Our community is vibrant and active, with over 40,000 followers on our activity feed. We welcome everyone to contribute, share, and learn from each other. Whether you're a researcher, engineer, or entrepreneur, you can find like-minded individuals and collaborate on projects.
#
# ## Customers and Partners
# We are proud to work with leading organizations such as AI2, Meta AI, Amazon, Google, Intel, Microsoft, Grammarly, and Writer. These partnerships demonstrate our commitment to making machine learning a reality for businesses and individuals alike.
#
# ## Careers
# If you're passionate about artificial intelligence and want to be part of a dynamic team, we invite you to explore our [job opportunities](https://huggingface.com/j obs). We offer a range of roles, from software engineering to research and marketing.
#
# ## Products and Services
# Our platform offers a range of products and services, including:
# * **Models**: With over 1 million models to browse, you can find the perfect model for your project.
# * **Datasets**: Access over 250,000 datasets to fuel your machine learning projects.
# * **Spaces**: Collaborate with others on projects and share your work with the world.
# * **Enterprise**: Get dedicated support, enterprise-grade security, and advanced features with our enterprise plan.
#
# ## Get Started
# Sign up for free today and join the Hugging Face community. With our open-source tools and collaboration platform, you can build, share, and use artificial intelligence like never before. [Sign up](https://huggingface.co/sign-up) and start building the future of AI.

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://huggingface.co/brand'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'github page', 'url': 'https://github.com/huggingface'}, {'type': 'linkedin page', 'url': 'https://www.linkedin.com/company/huggingface'}, {'type': 'twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'status page', 'url': 'https://status.huggingface.co/'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}]}
# # Hugging Face
# ## The AI Community Building the Future
# Hugging Face is a collaboration platform for machine learning (ML) enthusiasts, researchers, and organizations to build, share, and discover AI models, datasets, and applications. With a strong focus on community and open-source, Hugging Face aims to democratize access to good machine learning.
#
# ### Key Features
# * **1M+ Models**: Browse and use a vast collection of pre-trained models for various AI tasks
# * **250k+ Datasets**: Access and share datasets for ML tasks
# * **Spaces**: Host and collaborate on unlimited public models, datasets, and applications
# * **Enterprise Solutions**: Paid Compute and Enterprise solutions for security, access controls, and dedicated support
#
# ### Company Culture
# Hugging Face values community, openness, and collaboration. With a strong presence on social media and a active forum, the company fosters a culture of sharing knowledge, ideas, and resources. The company's mission is to make machine learning accessible to all, and its open-source approach reflects this goal.
#
# ### Customers and Partners
# Over 50,000 organizations, including AI2, Meta, Amazon, Google, Intel, Microsoft, Grammarly, and Writer, trust Hugging Face for their AI needs. The company's platform is used by researchers, developers, and businesses to build and deploy AI models.
#
# ### Careers and Jobs
# Hugging Face is constantly looking for talented individuals to join its team. From software engineers to researchers, the company offers a range of job opportunities to contribute to its mission of democratizing access to good machine learning.
#
# ### Get Started
# Sign up for a free account to explore the Hugging Face platform, browse models and datasets, and start building your own AI applications. For organizations, Hugging Face offers customizable solutions to meet specific needs.

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
