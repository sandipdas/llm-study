# %% [markdown]
# <a href="https://colab.research.google.com/github/sandipdas/llm-study/blob/main/Sandip_Note.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Usefull Links:
# - llm-engineering-resources: https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# - Google Colab: https://colab.research.google.com/drive/13bGsQwc6nryrpr5vfLXVnljww2c65IoF#scrollTo=2MdY3lybZWhj
# - LLM leaderboard: https://www.vellum.ai/llm-leaderboard
# - OpenRouter Models: https://openrouter.ai/models
# - Hugging Face Models: https://huggingface.co/models
# - Gemini: https://ai.google.dev/gemini-api/docs/openai
# - Ollama local Instance: http://localhost:11434/

# %% [markdown]
# ## Fast.ai Learning
# - [Fastbook for deep-learning](https://github.com/fastai/fastbook)
# - [fastai colab version](https://colab.research.google.com/github/fastai/fastbook/blob/master/01_intro.ipynb)
#
#
# ###Deep learning vocabulary
#
# <!-- |===== -->
# | Term | Meaning|
# |------|--------|
# |Label | The data that we're trying to predict, such as "dog" or "cat"|
# |Architecture | The _template_ of the model that we're trying to fit; the actual mathematical function that we're passing the input data and parameters to
# |Model | The combination of the architecture with a particular set of parameters
# |Parameters | The values in the model that change what task it can do, and are updated through model training
# |Fit | Update the parameters of the model such that the predictions of the model using the input data match the target labels
# |Train | A synonym for _fit_
# |Pretrained model | A model that has already been trained, generally using a large dataset, and will be fine-tuned
# |Fine-tune | Update a pretrained model for a different task
# |Epoch | One complete pass through the input data
# |Loss | A measure of how good the model is, chosen to drive training via SGD
# |Metric | A measurement of how good the model is, using the validation set, chosen for human consumption
# |Validation set | A set of data held out from training, used only for measuring how good the model is
# |Training set | The data used for fitting the model; does not include any data from the validation set
# |Overfitting | Training a model in such a way that it _remembers_ specific features of the input data, rather than generalizing well to data not seen during training
# |CNN | Convolutional neural network; a type of neural network that works particularly well for computer vision tasks

# %% [markdown]
# #
# Awesome! Since you're a **coder**, you already have an edge — your technical foundation is solid. Here's a **tailored LLM Learning Roadmap for Coders** that takes you from beginner to building your own GPT-powered tools.
#
#
# # 🚀 LLM Learning Roadmap for Coders
#
# ### 🟢 **Stage 1: LLM Basics & Core Concepts**
#
# | Skill              | What to Learn                                             | Resources                                                 |
# | ------------------ | --------------------------------------------------------- | --------------------------------------------------------- |
# | ✅ Python Refresher | Focus on `classes`, `APIs`, `requests`, `data processing` | Already good as a coder 👍                                |
# | 🧠 Neural Networks | Feedforward NN, backprop, loss functions                  | [NN Playground](https://playground.tensorflow.org)        |
# | 📊 Tokenization    | Byte-Pair Encoding (BPE), Token IDs                       | [OpenAI Tokenizer](https://platform.openai.com/tokenizer) |
# | 📚 NLP Essentials  | TF-IDF, embeddings, word vectors                          | Hugging Face NLP course                                   |
#
# ---
#
# ### 🟡 **Stage 2: Dive Into Transformers & LLMs**
#
# | Skill                 | What to Learn                                   | Resources                                                                           |
# | --------------------- | ----------------------------------------------- | ----------------------------------------------------------------------------------- |
# | 🔁 Transformers       | Self-attention, positional encoding             | [Deep Learning Basic](https://course.fast.ai/) 🔴 [The Illustrated Transformer](https://jalammar.github.io/illustrated-transformer/) 🔴 [Huggingface LLM course](https://huggingface.co/learn/llm-course/chapter1/1) 🔴 [how-transformer-works](https://www.deeplearning.ai/short-courses/how-transformer-llms-work/) |
# | 🏗️ GPT, BERT, LLaMA  | How encoder/decoder works, differences          | [YouTube: Yannic Kilcher / AI Coffee Break](https://www.youtube.com/@YannicKilcher) |
# | 🔌 Hugging Face       | Load GPT, BERT, etc. via `transformers` library | `transformers` library (Python)                                                     |
# | 📜 Prompt Engineering | Zero-shot, few-shot, chain-of-thought           | [OpenAI Cookbook](https://github.com/openai/openai-cookbook)                        |
#
# ---
#
# ### 🔵 **Stage 3: Fine-tuning & Vector Search (RAG)**
#
# | Skill                                   | What to Learn                                | Tools                             |
# | --------------------------------------- | -------------------------------------------- | --------------------------------- |
# | 🧠 Fine-tuning                          | Custom data, LoRA, PEFT                      | Hugging Face + Colab              |
# | 🧾 RAG (Retrieval-Augmented Generation) | Search + LLM = knowledge bots                | LangChain + Chroma/FAISS          |
# | 🧰 Vector DBs                           | Store/search embeddings                      | FAISS, Chroma, Weaviate           |
# | 🧪 Embeddings                           | SentenceTransformers, `openai.Embedding` API | `sentence-transformers`, `OpenAI` |
#
# ---
#
# ### 🔴 **Stage 4: Build & Deploy LLM Apps**
#
# | Project                      | Stack                               |
# | ---------------------------- | ----------------------------------- |
# | 📱 Chatbot with Memory       | LangChain + GPT + Chroma            |
# | 🔍 PDF/Doc Q\&A Bot          | RAG + LangChain + Streamlit         |
# | 📊 Codebase Search Assistant | LLM + VS Code plugin or CLI tool    |
# | 🔮 Astrology GPT App         | (your idea!) React Native + GPT API |
#
# | Deployment     | Tools                               |
# | -------------- | ----------------------------------- |
# | 🔧 APIs        | FastAPI / Flask                     |
# | ☁️ Deploy      | Render, Hugging Face Spaces, Vercel |
# | 🔒 Auth & Save | Firebase / Supabase                 |
#
# ---
#
# ### 💡 Mini Projects (Practice as You Learn)
#
# * [ ] 🗨️ Terminal GPT Chatbot (`openai.ChatCompletion`)
# * [ ] 🧾 Chat with your Markdown/PDF notes (LangChain + FAISS)
# * [ ] 💬 Telegram/Discord GPT Bot
# * [ ] 🔍 Search Engine + LLM Answerer (custom RAG)
#
# ---
#
# ## 🧭 Want a Learning Schedule?
#
# Let me know if you'd like:
#
# * 📆 A **4-week learning schedule**
# * 📁 A GitHub repo with starter code templates
# * 🎓 A list of **free YouTube tutorials** and Notebooks
#
# Just say the word, and I’ll build it for you.

# %% [markdown]
# ### Import Libs

# %%
# imports

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
import gradio as gr
from IPython.display import display
from diffusers import StableDiffusionXLPipeline
import torch
# Out:
# The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers and GPU quantization are unavailable.

# %% [markdown]
# ### Initialization of OAI

# %%
# Initialization

load_dotenv(override=True)
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')
BASE_URL = os.getenv('OPENROUTER_API_URL')
openai_api_key = os.getenv('OPENAI_API_KEY')
if openrouter_api_key:
    print(f"openrouter API Key exists and begins {openrouter_api_key[:8]}")
else:
    print("openrouter API Key not set")

MODEL = 'meta-llama/llama-4-maverick:free' # tool not supported
MODEL = "google/gemini-2.5-flash-preview-05-20"
openai = OpenAI(base_url=BASE_URL, api_key=openrouter_api_key)
# Out:
# openrouter API Key exists and begins sk-or-v1

# %% [markdown]
# ### System Message Init

# %%
system_message = "You are a helpful assistant for an Airline called FlightAI. "
system_message += "Give short, courteous answers, no more than 1 sentence. "
system_message += "Always be accurate. If you don't know the answer, say so."

# %% [markdown]
# ### Tool Example

# %%
# Let's start by making a useful function

ticket_prices = {"london": "$799", "paris": "$899", "tokyo": "$1400", "berlin": "$499", "kolkata": "$10"}

def get_ticket_price(destination_city):
    print(f"Tool get_ticket_price called for {destination_city}")
    city = destination_city.lower()
    return ticket_prices.get(city, "Unknown")

# %%
# There's a particular dictionary structure that's required to describe our function:

price_function = {
    "name": "get_ticket_price",
    "description": "Get the price of a return ticket to the destination city. Call this whenever you need to know the ticket price, for example when a customer asks 'How much is a ticket to this city'",
    "parameters": {
        "type": "object",
        "properties": {
            "destination_city": {
                "type": "string",
                "description": "The city that the customer wants to travel to",
            },
        },
        "required": ["destination_city"],
        "additionalProperties": False
    }
}

# %%
# And this is included in a list of tools:

tools = [{"type": "function", "function": price_function}]

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_message}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model=MODEL, messages=messages, tools=tools)

    if response.choices[0].finish_reason=="tool_calls":
        message = response.choices[0].message
        response, city = handle_tool_call(message)
        messages.append(message)
        messages.append(response)
        response = openai.chat.completions.create(model=MODEL, messages=messages)

    return response.choices[0].message.content

# %%
# We have to write that function handle_tool_call:

def handle_tool_call(message):
    tool_call = message.tool_calls[0]
    arguments = json.loads(tool_call.function.arguments)
    city = arguments.get('destination_city')
    price = get_ticket_price(city)
    response = {
        "role": "tool",
        "content": json.dumps({"destination_city": city,"price": price}),
        "tool_call_id": tool_call.id
    }
    return response, city

# %% [markdown]
# ### Gradio Chat UI

# %%
gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7869
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7869/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Tool get_ticket_price called for Kolkata

# %% [markdown]
# ### Image generation with huggingface

# %%
print("CUDA available:", torch.cuda.is_available())
print("Device name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU only")
# Out:
# CUDA available: False
# Device name: CPU only

# %%
# from diffusers import StableDiffusionXLPipeline
# import torch

pipe = StableDiffusionXLPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0",
    torch_dtype=torch.float32,
    variant="fp16"
)
pipe = pipe.to("cpu")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
# Generate image from prompt
prompt = "A futuristic city with neon lights and flying cars"
# image = pipe(prompt).images[0]
image = pipe(prompt, height=512, width=512).images[0]

# Display image in Jupyter Notebook
display(image)
# image.save("futuristic_city.png")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
